# %% [markdown]
# <a href="https://colab.research.google.com/github/baaihq/PortoFolio-2024/blob/main/OlahDataALLPT_SNBT2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd

# %%
# Memanggil file CSV dari github.
url = 'https://raw.githubusercontent.com/baaihq/PortoFolio-2024/main/AllUnivPoli-2024.csv'
df = pd.read_csv(url)

# %%
# Memanggil DataFrame df
df
# Out:
#          NAMA PERGURUAN TINGGI    KODE                         PROGRAM STUDI  \
# 0      UNIVERSITAS SYIAH KUALA  111001               PENDIDIKAN DOKTER HEWAN
# 1      UNIVERSITAS SYIAH KUALA  111002                          TEKNIK SIPIL
# 2      UNIVERSITAS SYIAH KUALA  111003                          TEKNIK MESIN
# 3      UNIVERSITAS SYIAH KUALA  111004                          TEKNIK KIMIA
# 4      UNIVERSITAS SYIAH KUALA  111005                            ARSITEKTUR
# ...                        ...     ...                                   ...
# 4763  POLITEKNIK NEGERI FAKFAK  931002                        TEKNIK LISTRIK
# 4764  POLITEKNIK NEGERI FAKFAK  931003                          TEKNIK SIPIL
# 4765  POLITEKNIK NEGERI FAKFAK  931004                 MANAJEMEN INFORMATIKA
# 4766  POLITEKNIK NEGERI FAKFAK  931005                         AGRO INDUSTRI
# 4767  POLITEKNIK NEGERI FAKFAK  931006  TEKNIK PERAWATAN DAN PERBAIKAN MESIN
#
#            JENJANG  DAYA TAMPUNG 2024  PEMINAT 2023 JENIS PORTOFOLIO
# 0          Sarjana                 84           548        Tidak Ada
# 1          Sarjana                 98           587        Tidak Ada
# 2          Sarjana                 42           231        Tidak Ada
# 3          Sarjana                 56           155        Tidak Ada
# 4          Sarjana                 56           296        Tidak Ada
# ...            ...                ...           ...              ...
# 4763  Diploma Tiga                 24             0        Tidak Ada
# 4764  Diploma Tiga                 48             3        Tidak Ada
# 4765  Diploma Tiga                 48             2        Tidak Ada
# 4766  Diploma Tiga                 36             0        Tidak Ada
# 4767  Diploma Tiga                 36             0        Tidak Ada
#
# [4768 rows x 7 columns]

# %%
# Mengecek tipe data dari DataFrame
df.dtypes
# Out:
# NAMA PERGURUAN TINGGI    object
# KODE                      int64
# PROGRAM STUDI            object
# JENJANG                  object
# DAYA TAMPUNG 2024         int64
# PEMINAT 2023              int64
# JENIS PORTOFOLIO         object
# dtype: object

# %%
# Merubah tipe data kolom ke-2 menjadi string.
df.iloc[:, 1] = df.iloc[:, 1].astype(str)

# Merubah tipe data kolom ke-4 dan ke-5 menjadi integer.
df.iloc[:, 4] = df.iloc[:, 4].astype(int)
df.iloc[:, 5] = df.iloc[:, 5].astype(int)

# %%
# Mengecek kembali tipe data dari DataFrame
df.dtypes
# Out:
# NAMA PERGURUAN TINGGI    object
# KODE                     object
# PROGRAM STUDI            object
# JENJANG                  object
# DAYA TAMPUNG 2024         int64
# PEMINAT 2023              int64
# JENIS PORTOFOLIO         object
# dtype: object

# %%
# Hitung Rasio Ketetatan (Daya Tampung / Peminat).
df['Rasio Keketetatan'] = df.apply(lambda row: row.iloc[4] / row.iloc[5] if row.iloc[5] != 0 else 0, axis=1) #Jika ada pembagi NOL, maka nilai 'Rasio Ketetatan' akan dituliskan menjadi NOL.

# %%
# Hitung Presentase (%) dari Rasio Ketetatan.
df['Presentase (%)'] = (df['Rasio Keketetatan'] * 100)

# %%
# Melihat tampilan baru dari DataFrame.
df
# Out:
#          NAMA PERGURUAN TINGGI    KODE                         PROGRAM STUDI  \
# 0      UNIVERSITAS SYIAH KUALA  111001               PENDIDIKAN DOKTER HEWAN
# 1      UNIVERSITAS SYIAH KUALA  111002                          TEKNIK SIPIL
# 2      UNIVERSITAS SYIAH KUALA  111003                          TEKNIK MESIN
# 3      UNIVERSITAS SYIAH KUALA  111004                          TEKNIK KIMIA
# 4      UNIVERSITAS SYIAH KUALA  111005                            ARSITEKTUR
# ...                        ...     ...                                   ...
# 4763  POLITEKNIK NEGERI FAKFAK  931002                        TEKNIK LISTRIK
# 4764  POLITEKNIK NEGERI FAKFAK  931003                          TEKNIK SIPIL
# 4765  POLITEKNIK NEGERI FAKFAK  931004                 MANAJEMEN INFORMATIKA
# 4766  POLITEKNIK NEGERI FAKFAK  931005                         AGRO INDUSTRI
# 4767  POLITEKNIK NEGERI FAKFAK  931006  TEKNIK PERAWATAN DAN PERBAIKAN MESIN
#
#            JENJANG  DAYA TAMPUNG 2024  PEMINAT 2023 JENIS PORTOFOLIO  \
# 0          Sarjana                 84           548        Tidak Ada
# 1          Sarjana                 98           587        Tidak Ada
# 2          Sarjana                 42           231        Tidak Ada
# 3          Sarjana                 56           155        Tidak Ada
# 4          Sarjana                 56           296        Tidak Ada
# ...            ...                ...           ...              ...
# 4763  Diploma Tiga                 24             0        Tidak Ada
# 4764  Diploma Tiga                 48             3        Tidak Ada
# 4765  Diploma Tiga                 48             2        Tidak Ada
# 4766  Diploma Tiga                 36             0        Tidak Ada
# 4767  Diploma Tiga                 36             0        Tidak Ada
#
#       Rasio Keketetatan  Presentase (%)
# 0              0.153285       15.328467
# 1              0.166951       16.695060
# 2              0.181818       18.181818
# 3              0.361290       36.129032
# 4              0.189189       18.918919
# ...                 ...             ...
# 4763           0.000000        0.000000
# 4764          16.000000     1600.000000
# 4765          24.000000     2400.000000
# 4766           0.000000        0.000000
# 4767           0.000000        0.000000
#
# [4768 rows x 9 columns]

# %%
# Simpan DataFrame ke file CSV
df.to_csv(r'PTN-PTKIN-PTVOKASI.csv', index = False)
