# %% [markdown]
# <a href="https://colab.research.google.com/github/baaihq/PortoFolio-2024/blob/main/GetData_SNBT2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import requests

# %%
# Mendefinisikan url untuk setiap Perguruan Tinggi yang akan diambil datanya.

# Daftar PTN AKADEMIK
url1 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=111'   #UNIVERSITAS SYIAH KUALA
url2 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=112'   #UNIVERSITAS MALIKUSSALEH
url3 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=113'   #UNIVERSITAS TEUKU UMAR
url4 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=114'   #UNIVERSITAS SAMUDRA
url5 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=115'   #ISBI ACEH
url6 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=121'   #UNIVERSITAS SUMATERA UTARA
url7 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=122'   #UNIVERSITAS NEGERI MEDAN
url8 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=131'   #UNIVERSITAS RIAU
url9 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=133'   #UNIVERSITAS MARITIM RAJA ALI HAJI
url10 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=141'  #UNIVERSITAS ANDALAS
url11 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=142'  #UNIVERSITAS NEGERI PADANG
url12 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=143'  #ISI PADANG PANJANG
url13 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=151'  #UNIVERSITAS JAMBI
url14 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=161'  #UNIVERSITAS BENGKULU
url15 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=171'  #UNIVERSITAS SRIWIJAYA
url16 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=181'  #UNIVERSITAS BANGKA BELITUNG
url17 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=191'  #UNIVERSITAS LAMPUNG
url18 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=192'  #INSTITUT TEKNOLOGI SUMATERA
url19 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=311'  #UNIVERSITAS SULTAN AGENG TIRTAYASA
url20 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=321'  #UNIVERSITAS INDONESIA
url21 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=323'  #UNIVERSITAS NEGERI JAKARTA
url22 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=324'  #UPN "VETERAN" JAKARTA
url23 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=331'  #UNIVERSITAS SINGAPERBANGSA KARAWANG
url24 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=332'  #INSTITUT TEKNOLOGI BANDUNG
url25 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=333'  #UNIVERSITAS PADJADJARAN
url26 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=334'  #UNIVERSITAS PENDIDIKAN INDONESIA
url27 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=335'  #ISBI BANDUNG
url28 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=341'  #INSTITUT PERTANIAN BOGOR
url29 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=342'  #UNIVERSITAS SILIWANGI
url30 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=351'  #UNIVERSITAS JENDERAL SOEDIRMAN
url31 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=352'  #UNIVERSITAS TIDAR
url32 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=353'  #UNIVERSITAS SEBELAS MARET
url33 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=354'  #ISI SURAKARTA
url34 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=355'  #UNIVERSITAS DIPONEGORO
url35 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=356'  #UNIVERSITAS NEGERI SEMARANG
url36 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=361'  #UNIVERSITAS GADJAH MADA
url37 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=362'  #UNIVERSITAS NEGERI YOGYAKARTA
url38 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=363'  #UPN "VETERAN" YOGYAKARTA
url39 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=364'  #ISI YOGYAKARTA
url40 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=371'  #UNIVERSITAS JEMBER
url41 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=372'  #UNIVERSITAS BRAWIJAYA
url42 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=373'  #UNIVERSITAS NEGERI MALANG
url43 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=381'  #UNIVERSITAS AIRLANGGA
url44 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=382'  #INSTITUT TEKNOLOGI SEPULUH NOPEMBER
url45 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=382'  #UNIVERSITAS NEGERI SURABAYA
url46 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=384'  #UNIVERSITAS TRUNOJOYO MADURA
url47 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=364'  #UNIVERSITAS TRUNOJOYO MADURA
url48 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=511'  #UNIVERSITAS TANJUNGPURA
url49 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=521'  #UNIVERSITAS PALANGKARAYA
url50 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=531'  #UNIVERSITAS LAMBUNG MANGKURAT
url51 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=541'  #UNIVERSITAS MULAWARMAN
url52 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn
= 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=532'  #UNIVERSITAS ISLAM NEGERI ANTASARI BANJARMASIN
url98 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=571'  #UIN SULTAN AJI MUHAMMAD IDRIS SAMARINDA
url99 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=622'  #UNIVERSITAS ISLAM NEGERI MATARAM
url100 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=713' #UNIVERSITAS ISLAM NEGERI ALAUDDIN
url101 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=732' #UNIVERSITAS ISLAM NEGERI DATOKARAMA PALU

# Daftar PTN VOKASI
url102 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=221' #POLITEKNIK NEGERI LHOKSEUMAWE
url103 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=222' #POLITEKNIK NEGERI MEDAN
url104 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=231' #POLITEKNIK NEGERI BATAM
url105 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=232' #POLITEKNIK NEGERI BENGKALIS
url106 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=241' #POLITEKNIK NEGERI PADANG
url107 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=242' #POLITEKNIK PERTANIAN NEGERI PAYAKUMBUH
url108 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=271' #POLITEKNIK NEGERI SRIWIJAYA
url109 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=281' #POLITEKNIK MANUFAKTUR NEGERI BANGKA BELITUNG
url110 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=291' #POLITEKNIK NEGERI LAMPUNG
url111 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=421' #POLITEKNIK NEGERI JAKARTA
url112 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=422' #POLITEKNIK NEGERI MEDIA KREATIF
url113 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=431' #POLITEKNIK NEGERI BANDUNG
url114 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=432' #POLITEKNIK MANUFAKTUR BANDUNG
url115 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=433' #POLITEKNIK NEGERI INDRAMAYU
url116 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=434' #POLITEKNIK NEGERI SUBANG
url117 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=452' #POLITEKNIK NEGERI SEMARANG
url118 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=453' #POLITEKNIK NEGERI CILACAP
url119 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=454' #POLITEKNIK MARITIM NEGERI INDONESIA
url120 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=471' #POLITEKNIK NEGERI BANYUWANGI
url121 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=472' #POLITEKNIK NEGERI JEMBER
url122 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=473' #POLITEKNIK NEGERI MADIUN
url123 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=474' #POLITEKNIK NEGERI MALANG
url124 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=481' #POLITEKNIK PERKAPALAN NEGERI SURABAYA
url125 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=482' #POLITEKNIK ELEKTRONIKA NEGERI SURABAYA (PENS)
url126 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=483' #POLITEKNIK NEGERI MADURA
url127 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=515' #POLITEKNIK NEGERI PONTIANAK
url128 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=516' #POLITEKNIK NEGERI KETAPANG
url129 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=517' #POLITEKNIK NEGERI SAMBAS
url130 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=536' #POLITEKNIK NEGERI BANJARMASIN
url131 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=537' #POLITEKNIK NEGERI TANAH LAUT
url132 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=552' #POLITEKNIK NEGERI NUNUKAN
url133 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=561' #POLITEKNIK PERTANIAN NEGERI SAMARINDA
url134 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=562' #POLITEKNIK NEGERI SAMARINDA
url135 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=563' #POLITEKNIK NEGERI BALIKPAPAN
url136 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=617' #POLITEKNIK NEGERI BALI
url137 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=641' #POLITEKNIK NEGERI KUPANG
url138 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=642' #POLITEKNIK PERTANIAN NEGERI KUPANG
url139 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=716' #POLITEKNIK NEGERI UJUNG PANDANG
url140 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=717' #POLITEKNIK PERTANIAN NEGERI PANGKAJENE KEPULAUAN
url141 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=727' #POLITEKNIK NEGERI MANADO
url142 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=728' #POLITEKNIK NEGERI NUSA UTARA
url143 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=831' #POLITEKNIK NEGERI AMBON
url144 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=832' #POLITEKNIK PERIKANAN NEGERI TUAL
url145 = 'https://sidata-ptn-snpmb.bppp.kemdikbud.go.id/ptn_sb.php?ptn=931' #POLITEKNIK NEGERI FAKFAK

# %%
# Mengirim permintaan GET ke URL dan menyimpan responsnya
for i in range(1, 146):
    exec(f"page{i} = requests.get(url{i})")

# %%
# Membuat objek BeautifulSoup untuk setiap halaman dari page1 hingga page145 dan menyimpannya dalam variabel soup1 hingga soup145.
for i in range(1, 146):
    exec(f"soup{i} = BeautifulSoup(page{i}.text, 'html')")

# %%
# Mencari tabel pertama dalam setiap objek BeautifulSoup dari soup1 hingga soup145 dan menyimpannya dalam variabel table1 hingga table145.
for i in range(1, 146):
    exec(f"table{i} = soup{i}.find_all('table')[0]")

# %%
# Mencari semua elemen th dalam setiap objek table dari table1 hingga table145 dan menyimpannya dalam variabel daftar_prodi1 hingga daftar_prodi145.
for i in range(1, 146):
    exec(f"daftar_prodi{i} = table{i}.find_all('th')")

# %%
# Mencari semua elemen th dalam tabel yang bersesuaian, mengambil teks dari setiap elemen tersebut, menghapus spasi ekstra, dan menyimpannya dalam variabel daftar_table_prodi11 hingga daftar_table_prodi145.
for i in range(1, 146):
    exec(f"daftar_table_prodi{i} = [title.text.strip() for title in daftar_prodi{i}]")

# Print daftar_table_prodi1 sebagai contoh tampilannya
print(daftar_table_prodi1)
# Out:
# ['NO', 'KODE', 'NAMA', 'JENJANG', 'DAYA TAMPUNG 2024', 'PEMINAT 2023', 'JENIS PORTOFOLIO']

# %%
import pandas as pd

# %%
# Membuat DataFrame baru dengan kolom yang sesuai dengan teks dari setiap elemen dalam daftar_table_prodi yang bersesuaian, dan menyimpan DataFrame tersebut dalam variabel df yang sesuai.
for i in range(1, 146):
    exec(f"df{i} = pd.DataFrame(columns = daftar_table_prodi{i})")

# %%
# Mengecek tampilan DataFrame1 (df1)
df1
# Out:
# Empty DataFrame
# Columns: [NO, KODE, NAMA, JENJANG, DAYA TAMPUNG 2024, PEMINAT 2023, JENIS PORTOFOLIO]
# Index: []

# %%
#Mencari semua elemen tr dalam setiap tabel dari table1 hingga table145 dan menyimpannya dalam variabel column_data1 hingga column_data101.
for i in range(1, 146):
    exec(f"column_data{i} = table{i}.find_all('tr')")

# %%
#Mengambil data dari setiap baris dalam column_data1 hingga column_data145, menghapus spasi ekstra, dan menambahkannya ke DataFrame yang sesuai.
for i in range(1, 146):
    for row in eval(f"column_data{i}[2:]"):
        row_data = row.find_all('td')
        individual_row_data = [data.text.strip() for data in row_data]
        length = len(eval(f"df{i}"))
        exec(f"df{i}.loc[length] = individual_row_data")

# %%
#Mengecek kembali tampilan df1
df1
# Out:
#     NO    KODE                     NAMA       JENJANG DAYA TAMPUNG 2024  \
# 0    1  111001  PENDIDIKAN DOKTER HEWAN       Sarjana                84
# 1    2  111002             TEKNIK SIPIL       Sarjana                98
# 2    3  111003             TEKNIK MESIN       Sarjana                42
# 3    4  111004             TEKNIK KIMIA       Sarjana                56
# 4    5  111005               ARSITEKTUR       Sarjana                56
# ..  ..     ...                      ...           ...               ...
# 70  71  111072                SEKRETARI  Diploma Tiga                14
# 71  72  111073     MANAJEMEN PERUSAHAAN  Diploma Tiga                14
# 72  73  111075                AKUNTANSI  Diploma Tiga                28
# 73  74  111076   KEUANGAN DAN PERBANKAN  Diploma Tiga                28
# 74  75  111077    MANAJEMEN INFORMATIKA  Diploma Tiga                28
#
#    PEMINAT 2023 JENIS PORTOFOLIO
# 0           548        Tidak Ada
# 1           587        Tidak Ada
# ...

# %%
#Mengecek tampilan df2
df2
# Out:
#     NO    KODE                                NAMA       JENJANG  \
# 0    1  112001                        TEKNIK SIPIL       Sarjana
# 1    2  112002                        TEKNIK MESIN       Sarjana
# 2    3  112003                        TEKNIK KIMIA       Sarjana
# 3    4  112004                      TEKNIK ELEKTRO       Sarjana
# 4    5  112005                     TEKNIK INDUSTRI       Sarjana
# 5    6  112006                  TEKNIK INFORMATIKA       Sarjana
# 6    7  112007                   TEKNIK ARSITEKTUR       Sarjana
# 7    8  112008                    AGROEKOTEKNOLOGI       Sarjana
# 8    9  112009                          AGRIBISNIS       Sarjana
# 9   10  112010                          AKUAKULTUR       Sarjana
# 10  11  112011                          KEDOKTERAN       Sarjana
# 11  12  112012                   PENDIDIKAN FISIKA       Sarjana
# 12  13  112013                    PENDIDIKAN KIMIA       Sarjana
# ...

# %%
#Mengecek tampilan df101
df101
# Out:
#   NO    KODE              NAMA  JENJANG DAYA TAMPUNG 2024 PEMINAT 2023  \
# 0  1  732001       INFORMATIKA  Sarjana                45           31
# 1  2  732002        ARSITEKTUR  Sarjana                18            5
# 2  3  732003  SISTEM INFORMASI  Sarjana                36           24
#
#   JENIS PORTOFOLIO
# 0        Tidak Ada
# 1        Tidak Ada
# 2        Tidak Ada

# %%
#Mengecek tampilan df145
df145
# Out:
#   NO    KODE                                              NAMA  \
# 0  1  931001  TEKNOLOGI REKAYASA KONSTRUKSI JALAN DAN JEMBATAN
# 1  2  931002                                    TEKNIK LISTRIK
# 2  3  931003                                      TEKNIK SIPIL
# 3  4  931004                             MANAJEMEN INFORMATIKA
# 4  5  931005                                     AGRO INDUSTRI
# 5  6  931006              TEKNIK PERAWATAN DAN PERBAIKAN MESIN
#
#            JENJANG DAYA TAMPUNG 2024 PEMINAT 2023 JENIS PORTOFOLIO
# 0  Sarjana Terapan                24            1        Tidak Ada
# 1     Diploma Tiga                24            0        Tidak Ada
# 2     Diploma Tiga                48            3        Tidak Ada
# 3     Diploma Tiga                48            2        Tidak Ada
# 4     Diploma Tiga                36            0        Tidak Ada
# 5     Diploma Tiga                36            0        Tidak Ada

# %%
#Menambahkan nama Perguruan Tinggi di kolom pertama pada setiap DataFrame.
df1.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS SYIAH KUALA')
df2.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS MALIKUSSALEH')
df3.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS TEUKU UMAR')
df4.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS SAMUDRA')
df5.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='ISBI ACEH')
df6.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS SUMATERA UTARA')
df7.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS NEGERI MEDAN')
df8.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS RIAU')
df9.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS MARITIM RAJA ALI HAJI')
df10.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS ANDALAS')
df11.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS NEGERI PADANG')
df12.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='ISI PADANG PANJANG')
df13.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS JAMBI')
df14.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS BENGKULU')
df15.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS SRIWIJAYA')
df16.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS BANGKA BELITUNG')
df17.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS LAMPUNG')
df18.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='INSTITUT TEKNOLOGI SUMATERA')
df19.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS SULTAN AGENG TIRTAYASA')
df20.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITA
insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS ISLAM NEGERI ALAUDDIN')
df101.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='UNIVERSITAS ISLAM NEGERI DATOKARAMA PALU')
df102.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI LHOKSEUMAWE')
df103.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI MEDAN')
df104.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI BATAM')
df105.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI BENGKALIS')
df106.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI PADANG')
df107.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK PERTANIAN NEGERI PAYAKUMBUH')
df108.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI SRIWIJAYA')
df109.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK MANUFAKTUR NEGERI BANGKA BELITUNG')
df110.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI LAMPUNG')
df111.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI JAKARTA')
df112.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI MEDIA KREATIF')
df113.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI BANDUNG')
df114.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK MANUFAKTUR BANDUNG')
df115.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI INDRAMAYU')
df116.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI SUBANG')
df117.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI SEMARANG')
df118.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI CILACAP')
df119.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK MARITIM NEGERI INDONESIA')
df120.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI BANYUWANGI')
df121.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI JEMBER')
df122.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI MADIUN')
df123.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI MALANG')
df124.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK PERKAPALAN NEGERI SURABAYA')
df125.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK ELEKTRONIKA NEGERI SURABAYA (PENS)')
df126.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI MADURA')
df127.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI PONTIANAK')
df128.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI KETAPANG')
df129.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI SAMBAS')
df130.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI BANJARMASIN')
df131.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI TANAH LAUT')
df132.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI NUNUKAN')
df133.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK PERTANIAN NEGERI SAMARINDA')
df134.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI SAMARINDA')
df135.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI BALIKPAPAN')
df136.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI BALI')
df137.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI KUPANG')
df138.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK PERTANIAN NEGERI KUPANG')
df139.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI UJUNG PANDANG')
df140.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK PERTANIAN NEGERI PANGKAJENE KEPULAUAN')
df141.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI MANADO')
df142.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI NUSA UTARA')
df143.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI AMBON')
df144.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK PERIKANAN NEGERI TUAL')
df145.insert(loc=1, column='NAMA PERGURUAN TINGGI', value='POLITEKNIK NEGERI FAKFAK')

# %%
#Mengecek kembali tampilan df1
df1
# Out:
#     NO    NAMA PERGURUAN TINGGI    KODE                     NAMA  \
# 0    1  UNIVERSITAS SYIAH KUALA  111001  PENDIDIKAN DOKTER HEWAN
# 1    2  UNIVERSITAS SYIAH KUALA  111002             TEKNIK SIPIL
# 2    3  UNIVERSITAS SYIAH KUALA  111003             TEKNIK MESIN
# 3    4  UNIVERSITAS SYIAH KUALA  111004             TEKNIK KIMIA
# 4    5  UNIVERSITAS SYIAH KUALA  111005               ARSITEKTUR
# ..  ..                      ...     ...                      ...
# 70  71  UNIVERSITAS SYIAH KUALA  111072                SEKRETARI
# 71  72  UNIVERSITAS SYIAH KUALA  111073     MANAJEMEN PERUSAHAAN
# 72  73  UNIVERSITAS SYIAH KUALA  111075                AKUNTANSI
# 73  74  UNIVERSITAS SYIAH KUALA  111076   KEUANGAN DAN PERBANKAN
# 74  75  UNIVERSITAS SYIAH KUALA  111077    MANAJEMEN INFORMATIKA
#
#          JENJANG DAYA TAMPUNG 2024 PEMINAT 2023 JENIS PORTOFOLIO
# 0        Sarjana                84          548        Tidak Ada
# ...

# %%
df20
# Out:
#     NO  NAMA PERGURUAN TINGGI    KODE                                 NAMA  \
# 0    1  UNIVERSITAS INDONESIA  321001                    PENDIDIKAN DOKTER
# 1    2  UNIVERSITAS INDONESIA  321002               PENDIDIKAN DOKTER GIGI
# 2    3  UNIVERSITAS INDONESIA  321003                           MATEMATIKA
# 3    4  UNIVERSITAS INDONESIA  321004                               FISIKA
# 4    5  UNIVERSITAS INDONESIA  321005                                KIMIA
# ..  ..                    ...     ...                                  ...
# 74  75  UNIVERSITAS INDONESIA  321073     ADMINISTRASI ASURANSI & AKTUARIA
# 75  76  UNIVERSITAS INDONESIA  321074                  HUBUNGAN MASYARAKAT
# 76  77  UNIVERSITAS INDONESIA  321075                   PERIKLANAN KREATIF
# 77  78  UNIVERSITAS INDONESIA  321076                            AKUNTANSI
# 78  79  UNIVERSITAS INDONESIA  321077  ADMINISTRASI KEUANGAN DAN PERBANKAN
#
#          JENJANG DAYA TAMPUNG 2024 PEMINAT 2023 JENIS PORTOFOLIO
# ...

# %%
df101
# Out:
#   NO                     NAMA PERGURUAN TINGGI    KODE              NAMA  \
# 0  1  UNIVERSITAS ISLAM NEGERI DATOKARAMA PALU  732001       INFORMATIKA
# 1  2  UNIVERSITAS ISLAM NEGERI DATOKARAMA PALU  732002        ARSITEKTUR
# 2  3  UNIVERSITAS ISLAM NEGERI DATOKARAMA PALU  732003  SISTEM INFORMASI
#
#    JENJANG DAYA TAMPUNG 2024 PEMINAT 2023 JENIS PORTOFOLIO
# 0  Sarjana                45           31        Tidak Ada
# 1  Sarjana                18            5        Tidak Ada
# 2  Sarjana                36           24        Tidak Ada

# %%
df145
# Out:
#   NO     NAMA PERGURUAN TINGGI    KODE  \
# 0  1  POLITEKNIK NEGERI FAKFAK  931001
# 1  2  POLITEKNIK NEGERI FAKFAK  931002
# 2  3  POLITEKNIK NEGERI FAKFAK  931003
# 3  4  POLITEKNIK NEGERI FAKFAK  931004
# 4  5  POLITEKNIK NEGERI FAKFAK  931005
# 5  6  POLITEKNIK NEGERI FAKFAK  931006
#
#                                                NAMA          JENJANG  \
# 0  TEKNOLOGI REKAYASA KONSTRUKSI JALAN DAN JEMBATAN  Sarjana Terapan
# 1                                    TEKNIK LISTRIK     Diploma Tiga
# 2                                      TEKNIK SIPIL     Diploma Tiga
# 3                             MANAJEMEN INFORMATIKA     Diploma Tiga
# 4                                     AGRO INDUSTRI     Diploma Tiga
# 5              TEKNIK PERAWATAN DAN PERBAIKAN MESIN     Diploma Tiga
#
#   DAYA TAMPUNG 2024 PEMINAT 2023 JENIS PORTOFOLIO
# 0                24            1        Tidak Ada
# 1                24            0        Tidak Ada
# ...

# %%
#Menghapus kolom pertama dari setiap DataFrame.
for i in range(1, 146):
    globals()[f'df{i}'] = globals()[f'df{i}'].drop(globals()[f'df{i}'].columns[0], axis=1)

#Merubah kolom judul "NAMA" menjadi "PROGRAM STUDI".
for i in range(1, 146):
    exec(f"df{i} = df{i}.rename(columns={{'NAMA': 'PROGRAM STUDI'}})")

# %%
#Mengecek kembali tampilan df1
df1
# Out:
#       NAMA PERGURUAN TINGGI    KODE            PROGRAM STUDI       JENJANG  \
# 0   UNIVERSITAS SYIAH KUALA  111001  PENDIDIKAN DOKTER HEWAN       Sarjana
# 1   UNIVERSITAS SYIAH KUALA  111002             TEKNIK SIPIL       Sarjana
# 2   UNIVERSITAS SYIAH KUALA  111003             TEKNIK MESIN       Sarjana
# 3   UNIVERSITAS SYIAH KUALA  111004             TEKNIK KIMIA       Sarjana
# 4   UNIVERSITAS SYIAH KUALA  111005               ARSITEKTUR       Sarjana
# ..                      ...     ...                      ...           ...
# 70  UNIVERSITAS SYIAH KUALA  111072                SEKRETARI  Diploma Tiga
# 71  UNIVERSITAS SYIAH KUALA  111073     MANAJEMEN PERUSAHAAN  Diploma Tiga
# 72  UNIVERSITAS SYIAH KUALA  111075                AKUNTANSI  Diploma Tiga
# 73  UNIVERSITAS SYIAH KUALA  111076   KEUANGAN DAN PERBANKAN  Diploma Tiga
# 74  UNIVERSITAS SYIAH KUALA  111077    MANAJEMEN INFORMATIKA  Diploma Tiga
#
#    DAYA TAMPUNG 2024 PEMINAT 2023 JENIS PORTOFOLIO
# ...

# %%
df19
# Out:
#                  NAMA PERGURUAN TINGGI    KODE  \
# 0   UNIVERSITAS SULTAN AGENG TIRTAYASA  311001
# 1   UNIVERSITAS SULTAN AGENG TIRTAYASA  311002
# 2   UNIVERSITAS SULTAN AGENG TIRTAYASA  311003
# 3   UNIVERSITAS SULTAN AGENG TIRTAYASA  311004
# 4   UNIVERSITAS SULTAN AGENG TIRTAYASA  311005
# 5   UNIVERSITAS SULTAN AGENG TIRTAYASA  311006
# 6   UNIVERSITAS SULTAN AGENG TIRTAYASA  311007
# 7   UNIVERSITAS SULTAN AGENG TIRTAYASA  311008
# 8   UNIVERSITAS SULTAN AGENG TIRTAYASA  311009
# 9   UNIVERSITAS SULTAN AGENG TIRTAYASA  311010
# 10  UNIVERSITAS SULTAN AGENG TIRTAYASA  311011
# 11  UNIVERSITAS SULTAN AGENG TIRTAYASA  311012
# 12  UNIVERSITAS SULTAN AGENG TIRTAYASA  311013
# 13  UNIVERSITAS SULTAN AGENG TIRTAYASA  311014
# 14  UNIVERSITAS SULTAN AGENG TIRTAYASA  311015
# 15  UNIVERSITAS SULTAN AGENG TIRTAYASA  311016
# 16  UNIVERSITAS SULTAN AGENG TIRTAYASA  311017
# 17  UNIVERSITAS SULTAN AGENG TIRTAYASA  311018
# 18  UNIVERSITAS SULTAN AGENG TIRTAYASA  311019
# ...

# %%
# Membuat list dari semua DataFrame
dfs = [globals()[f'df{i}'] for i in range(1, 146)]

# Mencetak tampilan dari setiap DataFrame dalam list
for i, df in enumerate(dfs, start=1):
    print(f"=== df{i} ===")
    from google.colab import files
    print(df)
# Out:
# Streaming output truncated to the last 5000 lines.
# 5                 15           17  Pendidikan Jasmani dan Olahraga
# 6                 32           17                        Tidak Ada
# 7                 32           26                        Tidak Ada
# 8                 36           31                        Tidak Ada
# 9                 30           16                        Tidak Ada
# 10                30           24                        Tidak Ada
# 11                30           22                        Tidak Ada
# 12                45           33                        Tidak Ada
# 13                62          207                        Tidak Ada
# 14                44          135                        Tidak Ada
# 15                51          988                        Tidak Ada
# 16                48           60                        Tidak Ada
# 17                60           94                        Tidak Ada
# ...

# %%
#Menyimpan DataFrame ke file CSV
for i in range(1, 146):
    exec(f"df{i}.to_csv(f'df{i}.csv', index = False)")
